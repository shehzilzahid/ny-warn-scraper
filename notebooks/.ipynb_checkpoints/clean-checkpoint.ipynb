# %%
import pandas as pd

# %%
nyc_warn = pd.read_csv('../data/warn.csv')

# %%
nyc_warn
# Out:
#     notice_date event_number                   reason  \
# 0      5/4/2020    2019-1630  Temporary Plant Closing
# 1     4/28/2020    2019-1629   Temporary Plant Layoff
# 2      5/7/2020    2019-1633             Plant Layoff
# 3      5/7/2020    2019-1631            Plant Closing
# 4      5/6/2020    2019-1632  Temporary Plant Closing
# ..          ...          ...                      ...
# 580   3/26/2020    2019-0931   Temporary Plant Layoff
# 581   3/21/2020    2019-0899   Temporary Plant Layoff
# 582   3/21/2020    2019-0898  Temporary Plant Closing
# 583   3/21/2020    2019-0897   Temporary Plant Layoff
# 584   3/25/2020    2019-0892   Temporary Plant Layoff
#
#                                                company  \
# 0            Michael Cetta Inc. dba Sparks Steak House
# 1                 Suffolk Transportation Service, Inc.
# 2    quantPORT Division of Jeffries Investment Advi...
# 3    Uber Technologies, Inc. (JUMP venture aka Soci...
# ...

# %%
nyc_warn.isna()
# Out:
#      notice_date  event_number  reason  company  address  county  phone  \
# 0          False         False   False    False    False   False  False
# 1          False         False   False    False    False   False  False
# 2          False         False   False    False    False   False  False
# 3          False         False   False    False    False   False  False
# 4          False         False   False    False    False   False  False
# ..           ...           ...     ...      ...      ...     ...    ...
# 580        False         False   False    False    False   False  False
# 581        False         False   False    False    False   False  False
# 582        False         False   False    False    False   False  False
# 583        False         False   False    False    False   False  False
# 584        False         False   False    False    False   False  False
#
#      business_type  affected  total_employees  layoff_date  dislocation  \
# ...

# %%
nyc_warn.isna().sum()
# Out:
# notice_date        0
# event_number       0
# reason             0
# company            0
# address            1
# county             0
# phone              0
# business_type      0
# affected           0
# total_employees    0
# layoff_date        0
# dislocation        0
# union              0
# classification     0
# dtype: int64

# %%
nyc_warn.iloc[138].isna().sum()
# Out:
# 1

# %%
nyc_warn
# Out:
#     notice_date event_number                   reason  \
# 0      5/4/2020    2019-1630  Temporary Plant Closing
# 1     4/28/2020    2019-1629   Temporary Plant Layoff
# 2      5/7/2020    2019-1633             Plant Layoff
# 3      5/7/2020    2019-1631            Plant Closing
# 4      5/6/2020    2019-1632  Temporary Plant Closing
# ..          ...          ...                      ...
# 580   3/26/2020    2019-0931   Temporary Plant Layoff
# 581   3/21/2020    2019-0899   Temporary Plant Layoff
# 582   3/21/2020    2019-0898  Temporary Plant Closing
# 583   3/21/2020    2019-0897   Temporary Plant Layoff
# 584   3/25/2020    2019-0892   Temporary Plant Layoff
#
#                                                company  \
# 0            Michael Cetta Inc. dba Sparks Steak House
# 1                 Suffolk Transportation Service, Inc.
# 2    quantPORT Division of Jeffries Investment Advi...
# 3    Uber Technologies, Inc. (JUMP venture aka Soci...
# ...

# %%
nyc_warn.iloc[138].isna().sum()
# Out:
# 1

# %%
nyc_warn.drop(['address'], axis="columns")
# Out:
#     notice_date event_number                   reason  \
# 0      5/4/2020    2019-1630  Temporary Plant Closing
# 1     4/28/2020    2019-1629   Temporary Plant Layoff
# 2      5/7/2020    2019-1633             Plant Layoff
# 3      5/7/2020    2019-1631            Plant Closing
# 4      5/6/2020    2019-1632  Temporary Plant Closing
# ..          ...          ...                      ...
# 580   3/26/2020    2019-0931   Temporary Plant Layoff
# 581   3/21/2020    2019-0899   Temporary Plant Layoff
# 582   3/21/2020    2019-0898  Temporary Plant Closing
# 583   3/21/2020    2019-0897   Temporary Plant Layoff
# 584   3/25/2020    2019-0892   Temporary Plant Layoff
#
#                                                company           county  \
# 0            Michael Cetta Inc. dba Sparks Steak House  New York County
# 1                 Suffolk Transportation Service, Inc.   Suffolk County
# 2    quantPORT Division of Jeffries Investment Advi...  New York County
# ...
