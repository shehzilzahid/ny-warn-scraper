# %%
# import pandas
import pandas as pd
import numpy as np

# %%
# read your csv in
df = pd.read_csv('../data/warn.csv')

# %%
df
# Out:
#      notice_date event_number                   reason  \
# 0       5/4/2020    2019-1630  Temporary Plant Closing
# 1      4/28/2020    2019-1629   Temporary Plant Layoff
# 2       5/7/2020    2019-1633             Plant Layoff
# 3       5/7/2020    2019-1631            Plant Closing
# 4       5/6/2020    2019-1632  Temporary Plant Closing
# ...          ...          ...                      ...
# 1247    1/8/2020    2019-0210            Plant Closing
# 1248    1/6/2020    2019-0207            Plant Closing
# 1249  12/27/2019    2019-0206  Temporary Plant Closing
# 1250  12/30/2019    2019-0205            Plant Closing
# 1251  12/30/2019    2019-0201            Plant Closing
#
#                                                 company  \
# 0             Michael Cetta Inc. dba Sparks Steak House
# 1                  Suffolk Transportation Service, Inc.
# 2     quantPORT Division of Jeffries Investment Advi...
# 3     Uber Technologies, Inc. (JUMP venture aka Soci...
# ...

# %%
df['business_type'].unique()
# Out:
# array(['Restaurant', 'Transportation', 'Investment advisors',
#        'On-demand electric bikes & scooters', 'Casino',
#        'Online marketplace for arranging or offering lodging, primarily homestays, or tourism experiences.',
#        'Hotel', 'Drug distribution company', 'Home Furnishing',
#        'Home Furnishings', 'Payroll & HR Services', 'Employment Agency',
#        'Provide complete source for lab systems and sustainable, adaptable casework of painted steel, wood or stainless steel complete with specified fixtures, fume hoods and work surfaces.',
#        'Theatrical, architectural, film and video lighting',
#        'Commercial Printing', 'American online travel company',
#        'Building maintenance and cleaning services', 'Event Company',
#        'Car cleaning services', 'Realty Management', 'Seafood Restaurant',
#        'All Luxury SUV, Cars, Vans Rentals', 'Car rentals',
#        'Dental equipment distribution and manufacturing',
# ...

# %%
df.loc[df['business_type'].isin(['Online marketplace for arranging or offering lodging, primarily homestays, or tourism experiences.', 
                                 'American online travel company', 
                                 'Travel Agency', 
                                 'Airline Services',
                                 'Airport Services', 
                                 'Travel Center',
                                 'Airline Sales',
                                 'Airline']), 'business_type'] = 'Travel and Tourism'

# %%
df.loc[df['business_type'].isin(['Auto Shop', 
                                 'Car dealership', 
                                 'Auto dealership',
                                 'Car Dealership',
                                 'Auto Body Shop', 
                                 'Auto Sales', 
                                 'Auto Dealer', 
                                 'Custom auto interior parts for classic car restoration',
                                 'Automobile Sales', 
                                 'Motor Vehicle Sales', 
                                 'Trucking company providing freight transportation services and hauling cargo']), 'business_type'] = 'Auto Dealership'

# %%
df.loc[df['business_type'].isin(['Seafood Restaurant', 
                                 'Coffee Shop', 
                                 'Same-day grocery delivery and pick-up service',
                                 'Catering', 
                                 'Hotel',
                                 'Catering business', 
                                 'Hotel and Restaurant', 
                                 'Modern Japanese restaurant', 
                                 'Wholesale Bakery', 
                                 'Broth Shop', 
                                 'Outdoor Lounge/Restaurant', 
                                 'Bakery', 
                                 'Food preparation and delivery services', 
                                 'Airport Restaurant',
                                 'Catering Staffing', 
                                 'Resort Hotel', 
                                 'Hotel and Restaurant', 
                                 'Resort', 
                                 'Ski Resort',
                                 'On-demand electric bikes & scooters', 
                                 'All Luxury SUV, Cars, Vans Rentals', 
                                 'Car rentals', 'On-demand car service', 
                                 'Transporation Services', 
                                 'Car Rentals',
                                 'Car Rental', 
                                 'Transportation Carrier', 
                                 'Rental Car', 
                                 'Bus Transit', 
                                 'Limousine Service',
                                 'Transportation Company', 
                                 'Parking Service/Locations', 
                                 'Transportation and Logistics',
                                 'Transportation', 
                                 'Catering/Event Venue',
                                 'Event Planners/Caterers'
                                 'Creamery', 
                                 'Event Planning'
                                 'Venue',
                                 'Event Venue',
                                 'Restaurants',
                                 'Music Venue',
                                 'Restaurant',
                                 'Event Company',
                                 'Party Rental',
                                 'Executive Events Company',
                                 'Paratransit transportation throughout the 5 boroughs of New York City',
                                 'Parking facility servicing the LaGuardia Airport', 
                                 'Transportation Services']), 'business_type'] = 'Hospitality'

# %%
df.loc[df['business_type'].isin(['Clothing Retail', 
                                 'Retail clothing store', 
                                 'Internet Retail', 
                                 'Suit Retail', 
                                 'Paper Retailer', 
                                 'Musical Instrument Sales', 
                                 'Animal Feed Store', 
                                 'Sporting Goods', 
                                 'Undergarments', 
                                 'Footwear',
                                 'Clothing Store', 
                                 'Cellular Sales', 
                                 'Toy Store', 
                                 'an American clothing brand and retailer', 
                                 'Denim Retailer', 
                                 'Airport Retail', 
                                 'Mattress Store', 
                                 'Winter Sports Center', 
                                 'Furniture Store',
                                 'Retail  and auto store', 
                                 'Retail store',
                                 'Retail Store', 
                                 'Retail Corporate offices',
                                 'Clothing Retail',
                                 'Optical Retailer',
                                 'Jewelry Sales',
                                 'Clothing Manufacturer', 
                                 'Footwear Retailer', 
                                 'Musical Instrument Rental', 
                                 'Machine Shop',
                                 'Jewelry Store',
                                 'Hobby, Toy, and Game Stores',
                                 'Closets and Storage','Electrical Supply Store',
                                 'Retail Corporate offices',
                                 'Operates online content and retail properties',
                                 'Shoe Store']), 'business_type'] = 'Retail'

# %%
df.loc[df['business_type'].isin(['Manufacturer', 
                                'Dental equipment distribution and manufacturing',
                                'Producer of LED safety lighting',
                                'Air Compressor Manufacturer',
                                'Cosmetic Manufacturing',
                                'Cosmetic Manufacturer',
                                'Fiberglass Manufacturing', 
                                'Custom fabricator of architectural metal',
                                'Iron Manufacturer',
                                'Façade Manufacturing',
                                'Fragrance Manufacturing',
                                'Pool Manufacturer',
                                'Building Materials Supplier',
                                'Plastic Manufacturing',
                                'Bedding, Bath, and window Manufacturing', 
                                'Architectural Metal and Glass Manufacturing', 
                                'Water Manufacturer', 
                                'Electronic Instrument Manufacturer',
                                'Retail & Light Manufacturing', 
                                'Watch Manufacturing',
                                'Award Manufacturer', 
                                'Perfume Manufacturing', 
                                'Clothing Manufacturing',
                                'Manufacturer of capacitors', 
                                'Manufacturer of air & gas compressors',
                                'Welding and Soldering Equipment Manufacturing',
                                'Electronic Instrument Manufacturer'
                                ]), 'business_type'] = 'Manufacturing'

# %%
df.loc[df['business_type'].isin(['Gym',
                                'Eye Care',
                                'Home Health Care',
                                'Dentist',
                                'Family planning services',
                                'Diagnostic Imaging Center',
                                'Obstetrics and Gynecology',
                                'Healthcare',
                                'Ophthalmologist',
                                'Wellness Center',
                                'Medical Billing',
                                'Healthcare Center', 
                                'Medical Imaging',
                                'Ophthalmologist/Optician',
                                'Online Fitness',
                                'Orthopedics',
                                'Day Spa',
                                'Neurology Health Care Provider',
                                'Optometry Offices',
                                'Health Care Provider - Mammography',
                                'Physcial and Occupational Therapy',
                                'Wellness Center',
                                'Medical Equipment', 
                                'Ambulatory Surgery Center',
                                'Physcial Therapist', 
                                'Acute Care Hospital',
                                'Emergency Relief',
                                'Leading  healthcare improvement company',
                                'Clinical Services', 'General Medical & Surgical Hospital',
                                'Health Plans',
                                 'Nursing Home',
                                'Fitness Club'
                                ]), 'business_type'] = 'Health Care'

# %%
df.loc[df['business_type'].isin(['Drug distribution company',
                                'Lumber and Building Material Distribution',
                                'Wholesale Distribution',
                                'Designer, Distribution and Licensor of Apparel', 
                                'Food Distribution',
                                'Manages the production and distribution for Gannett’s domestic daily newspapers',
                                'Wholesale distributor of Janitorial and Industrial Supplies',
                                'Produces  and distributes numerous brands of bottled water across North America.',
                                'Wholesale distributor of Janitorial and Industrial Supplies', 
                                ]), 'business_type'] = 'Distribution'

# %%
df.to_csv('../data/business.csv', index=False)
